# %% [markdown]
# # INSTALLING ANACONDA

# %%
# !echo $PYTHONPATH

# %%
# %env PYTHONPATH=

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX

# %%
# %%bash
# conda install --channel defaults conda python=3.6 --yes
# conda update --channel defaults --all --yes

# %%
import sys
_ = (sys.path
        .append("/usr/local/lib/python3.6/site-packages"))

# %%
# !conda install --channel conda-forge featuretools --yes

# %% [markdown]
# #DeepPurpose

# %%
# !git clone https://github.com/kexinhuang12345/DeepPurpose.git

# %%
# %%bash
# cd /content/DeepPurpose
# echo -y | conda env create -f environment.yml
# source activate DeepPurpose
#
#
# python play.py
#
# # play.py contain the following lines and is in DeepPurpose folder
#
# # from DeepPurpose import oneliner
# # from DeepPurpose.dataset import *
# # oneliner.repurpose(*load_SARS_CoV2_Protease_3CL(), *load_antiviral_drugs(no_cid = True))
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
# libgomp-9.3.0        | 378 KB    | ########## | 100%
# notebook-6.0.3       | 6.2 MB    | ########## | 100%
# libxml2-2.9.9        | 1.3 MB    | ########## | 100%
# mistune-0.8.4        | 54 KB     | ########## | 100%
# python-3.7.7         | 45.0 MB   | ########## | 100%
# backcall-0.1.0       | 13 KB     | ########## | 100%
# cffi-1.14.0          | 221 KB    | ########## | 100%
# webencodings-0.5.1   | 12 KB     | ########## | 100%
# setuptools-46.1.3    | 634 KB    | ########## | 100%
# pytorch-1.4.0        | 432.9 MB  | ########## | 100%
# pycparser-2.20       | 94 KB     | ########## | 100%
# prompt-toolkit-3.0.4 | 233 KB    | ########## | 100%
# sqlite-3.31.1        | 1.1 MB    | ########## | 100%
# icu-58.2             | 22.6 MB   | ########## | 100%
# lz4-3.0.2            | 43 KB     | ########## | 100%
# importlib_metadata-1 | 3 KB      | ########## | 100%
# zeromq-4.3.1         | 648 KB    | ########## | 100%
# kiwisolver-1.1.0     | 86 KB     | ########## | 100%
# joblib-0.14.1        | 198 KB    | ########## | 100%
# defusedxml-0.6.0     | 22 KB     | ########## | 100%
# matplotlib-base-3.1. | 5.0 MB    | ########## | 100%
# nbformat-5.0.4       | 98 KB     | ########## | 100%
# xz-5.2.4             | 375 KB    | ########## | 100%
# ipython-7.13.0       | 1.1 MB    | ########## | 100%
# parso-0.6.2          | 66 KB     | ########## | 100%
# numpy-base-1.18.1    | 4.2 MB    | ########## | 100%
# torchvision-0.5.0    | 9.1 MB    | ########## | 100%
# entrypoints-0.3      | 13 KB     | ########## | 100%
# descriptastorus-2.2. | 63 KB     | ########## | 100%
# ipykernel-5.1.4      | 160 KB    | ########## | 100%
# openblas-0.3.10      | 8.3 MB    | ########## | 100%
# libgcc-ng-9.3.0      | 7.8 MB    | ########## | 100%
# jinja2-2.11.1        | 94 KB     | ########## | 100%
# llvm-openmp-9.0.1    | 782 KB    | ########## | 100%
# cairo-1.14.12        | 906 KB    | ########## | 100%
# openssl-1.1.1f       | 2.1 MB    | ########## | 100%
# readline-8.0         | 281 KB    | ########## | 100%
# blas-1.0             | 1 KB      | ########## | 100%
# numpy-1.18.1         | 5.2 MB    | ########## | 100%
# tk-8.6.8             | 3.1 MB    | ########## | 100%
# pyparsing-2.4.6      | 59 KB     | ########## | 100%
# attrs-19.3.0         | 35 KB     | ########## | 100%
# zlib-1.2.11          | 106 KB    | ########## | 100%
# libboost-1.67.0      | 13.0 MB   | ########## | 100%
# testpath-0.4.4       | 85 KB     | ########## | 100%
# _libgcc_mutex-0.1    | 3 KB      | ########## | 100%
# six-1.14.0           | 13 KB     | ########## | 100%
# gstreamer-1.14.5     | 4.5 MB    | ########## | 100%
# matplotlib-3.1.3     | 21 KB     | ########## | 100%
# py-boost-1.67.0      | 278 KB    | ########## | 100%
# fontconfig-2.13.0    | 296 KB    | ########## | 100%
# jupyter_core-4.6.3   | 71 KB     | ########## | 100%
# jedi-0.16.0          | 778 KB    | ########## | 100%
# intel-openmp-2019.4  | 729 KB    | ########## | 100%
# ncurses-6.2          | 991 KB    | ########## | 100%
# libtiff-4.1.0        | 447 KB    | ########## | 100%
# mkl-2019.4           | 131.2 MB  | ########## | 100%
# markupsafe-1.1.1     | 27 KB     | ########## | 100%
# mkl-service-2.3.0    | 64 KB     | ########## | 100%
# decorator-4.4.2      | 11 KB     | ########## | 100%
# glib-2.58.3          | 3.3 MB    | ########## | 100%
# pexpect-4.8.0        | 47 KB     | ########## | 100%
# scikit-plot-0.3.7    | 25 KB     | ########## | 100%
# jpeg-9b              | 214 KB    | ########## | 100%
# pyzmq-18.1.1         | 452 KB    | ########## | 100%
# freetype-2.9.1       | 882 KB    | ########## | 100%
# zstd-1.3.7           | 905 KB    | ########## | 100%
# mkl_fft-1.0.15       | 169 KB    | ########## | 100%
# libopenblas-0.3.10   | 7.8 MB    | ########## | 100%
# scipy-1.4.1          | 18.8 MB   | ########## | 100%
# nbconvert-5.6.1      | 487 KB    | ########## | 100%
# gst-plugins-base-1.1 | 6.8 MB    | ########## | 100%
# wcwidth-0.1.9        | 20 KB     | ########## | 100%
# libffi-3.2.1         | 47 KB     | ########## | 100%
# jsonschema-3.2.0     | 45 KB     | ########## | 100%
# pickleshare-0.7.5    | 9 KB      | ########## | 100%
# mkl_random-1.1.0     | 372 KB    | ########## | 100%
# importlib-metadata-1 | 42 KB     | ########## | 100%
# pytz-2019.3          | 237 KB    | ########## | 100%
# python_abi-3.7       | 4 KB      | ########## | 100%
# terminado-0.8.3      | 23 KB     | ########## | 100%
# pygments-2.6.1       | 683 KB    | ########## | 100%
# libiconv-1.15        | 2.0 MB    | ########## | 100%
# bleach-3.1.0         | 110 KB    | ########## | 100%
# gettext-0.19.8.1     | 3.6 MB    | ########## | 100%
# expat-2.2.9          | 191 KB    | ########## | 100%
# sip-4.19.8           | 290 KB    | ########## | 100%
# pyqt-5.9.2           | 5.7 MB    | ########## | 100%
# scikit-learn-0.22.1  | 7.1 MB    | ########## | 100%
# lz4-c-1.8.3          | 187 KB    | ########## | 100%
# rdkit-2020.03.3.0    | 24.8 MB   | ########## | 100%
# libblas-3.8.0        | 11 KB     | ########## | 100%
# prometheus_client-0. | 38 KB     | ########## | 100%
# pandoc-2.2.3.2       | 14.0 MB   | ########## | 100%
# zipp-2.2.0           | 9 KB      | ########## | 100%
# libstdcxx-ng-9.3.0   | 4.0 MB    | ########## | 100%
# tqdm-4.44.1          | 48 KB     | ########## | 100%
# certifi-2019.11.28   | 149 KB    | ########## | 100%
# libcblas-3.8.0       | 11 KB     | ########## | 100%
# ld_impl_linux-64-2.3 | 617 KB    | ########## | 100%
# jupyter_client-6.1.2 | 74 KB     | ########## | 100%
# libedit-3.1.20191231 | 121 KB    | ########## | 100%
# ipython_genutils-0.2 | 21 KB     | ########## | 100%
# traitlets-4.3.3      | 133 KB    | ########## | 100%
# qt-5.9.7             | 68.5 MB   | ########## | 100%
# wheel-0.34.2         | 24 KB     | ########## | 100%
# liblapack-3.8.0      | 11 KB     | ########## | 100%
# ca-certificates-2020 | 125 KB    | ########## | 100%
# pandocfilters-1.4.2  | 9 KB      | ########## | 100%
# pip-20.0.2           | 1.0 MB    | ########## | 100%
# ninja-1.9.0          | 1.6 MB    | ########## | 100%
# send2trash-1.5.0     | 12 KB     | ########## | 100%
# pillow-7.0.0         | 598 KB    | ########## | 100%
# pandas-1.0.3         | 11.1 MB   | ########## | 100%
# pcre-8.43            | 257 KB    | ########## | 100%
# gmp-6.2.0            | 811 KB    | ########## | 100%
# cudatoolkit-10.1.243 | 347.4 MB  | ########## | 100%
# ptyprocess-0.6.0     | 15 KB     | ########## | 100%
# dbus-1.13.6          | 602 KB    | ########## | 100%
# libsodium-1.0.16     | 306 KB    | ########## | 100%
# _openmp_mutex-4.5    | 22 KB     | ########## | 100%
# pyrsistent-0.16.0    | 89 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working... Ran pip subprocess with arguments:
# ['/usr/local/envs/DeepPurpose/bin/python', '-m', 'pip', 'install', '-U', '-r', '/content/DeepPurpose/condaenv.eluwkyej.requirements.txt']
# Pip subprocess output:
# Collecting alabaster==0.7.12
#   Downloading alabaster-0.7.12-py2.py3-none-any.whl (14 kB)
# Collecting autograd==1.3
#   Using cached autograd-1.3.tar.gz (38 kB)
# Collecting autograd-gamma==0.4.2
#   Downloading autograd_gamma-0.4.2-py2.py3-none-any.whl (3.8 kB)
# Collecting babel==2.8.0
#   Downloading Babel-2.8.0-py2.py3-none-any.whl (8.6 MB)
# Collecting chardet==3.0.4
#   Downloading chardet-3.0.4-py2.py3-none-any.whl (133 kB)
# Collecting docutils==0.16
#   Downloading docutils-0.16-py2.py3-none-any.whl (548 kB)
# Collecting future==0.18.2
#   Using cached future-0.18.2.tar.gz (829 kB)
# Collecting idna==2.9
#   Downloading idna-2.9-py2.py3-none-any.whl (58 kB)
# Collecting imagesize==1.2.0
#   Downloading imagesize-1.2.0-py2.py3-none-any.whl (4.8 kB)
# Collecting lifelines==0.24.3
#   Using cached lifelines-0.24.3-py2.py3-none-any.whl (417 kB)
# Collecting packaging==20.3
#   Downloading packaging-20.3-py2.py3-none-any.whl (37 kB)
# Collecting prettytable==0.7.2
#   Downloading prettytable-0.7.2.tar.bz2 (21 kB)
# Collecting requests==2.23.0
#   Downloading requests-2.23.0-py2.py3-none-any.whl (58 kB)
# Collecting snowballstemmer==2.0.0
#   Downloading snowballstemmer-2.0.0-py2.py3-none-any.whl (97 kB)
# Collecting subword-nmt==0.3.7
#   Using cached subword_nmt-0.3.7-py2.py3-none-any.whl (26 kB)
# Collecting urllib3==1.25.8
#   Downloading urllib3-1.25.8-py2.py3-none-any.whl (125 kB)
# Processing /root/.cache/pip/wheels/a1/b6/7c/0e63e34eb06634181c63adacca38b79ff8f35c37e3c13e3c02/wget-3.2-py3-none-any.whl
# Requirement already satisfied, skipping upgrade: numpy>=1.12 in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from autograd==1.3->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 2)) (1.18.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.2.0 in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from autograd-gamma==0.4.2->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 3)) (1.4.1)
# Requirement already satisfied, skipping upgrade: pytz>=2015.7 in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from babel==2.8.0->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 4)) (2019.3)
# Requirement already satisfied, skipping upgrade: matplotlib>=3.0 in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from lifelines==0.24.3->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 10)) (3.1.3)
# Requirement already satisfied, skipping upgrade: pandas>=0.23.0 in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from lifelines==0.24.3->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 10)) (1.0.3)
# Requirement already satisfied, skipping upgrade: six in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from packaging==20.3->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 11)) (1.14.0)
# Requirement already satisfied, skipping upgrade: pyparsing>=2.0.2 in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from packaging==20.3->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 11)) (2.4.6)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from requests==2.23.0->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 13)) (2019.11.28)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from matplotlib>=3.0->lifelines==0.24.3->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 10)) (0.10.0)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from matplotlib>=3.0->lifelines==0.24.3->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 10)) (1.1.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from matplotlib>=3.0->lifelines==0.24.3->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 10)) (2.8.1)
# Requirement already satisfied, skipping upgrade: setuptools in /usr/local/envs/DeepPurpose/lib/python3.7/site-packages (from kiwisolver>=1.0.1->matplotlib>=3.0->lifelines==0.24.3->-r /content/DeepPurpose/condaenv.eluwkyej.requirements.txt (line 10)) (46.1.3.post20200325)
# Building wheels for collected packages: autograd, future, prettytable
#   Building wheel for autograd (setup.py): started
#   Building wheel for autograd (setup.py): finished with status 'done'
#   Created wheel for autograd: filename=autograd-1.3-py3-none-any.whl size=47990 sha256=ebe97a8437a63d2a7678e4e108e242e829df71a9b8f93267b27db6a80caf19b6
#   Stored in directory: /root/.cache/pip/wheels/ef/32/31/0e87227cd0ca1d99ad51fbe4b54c6fa02afccf7e483d045e04
#   Building wheel for future (setup.py): started
#   Building wheel for future (setup.py): finished with status 'done'
#   Created wheel for future: filename=future-0.18.2-py3-none-any.whl size=491058 sha256=9a4f3e378043ae3b72590597337e01d02a9e25afcd8704a2a3200136dfbd4a5f
#   Stored in directory: /root/.cache/pip/wheels/56/b0/fe/4410d17b32f1f0c3cf54cdfb2bc04d7b4b8f4ae377e2229ba0
#   Building wheel for prettytable (setup.py): started
#   Building wheel for prettytable (setup.py): finished with status 'done'
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13698 sha256=48d4be56248ac79f44aed23fe4c211931104a8485febcc424c2268a5eb782bc7
#   Stored in directory: /root/.cache/pip/wheels/8c/76/0b/eb9eb3da7e2335e3577e3f96a0ae9f74f206e26457bd1a2bc8
# Successfully built autograd future prettytable
# Installing collected packages: alabaster, future, autograd, autograd-gamma, babel, chardet, docutils, idna, imagesize, lifelines, packaging, prettytable, urllib3, requests, snowballstemmer, subword-nmt, wget
# Successfully installed alabaster-0.7.12 autograd-1.3 autograd-gamma-0.4.2 babel-2.8.0 chardet-3.0.4 docutils-0.16 future-0.18.2 idna-2.9 imagesize-1.2.0 lifelines-0.24.3 packaging-20.3 prettytable-0.7.2 requests-2.23.0 snowballstemmer-2.0.0 subword-nmt-0.3.7 urllib3-1.25.8 wget-3.2
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate DeepPurpose
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Save path not found or given and set to default: './save_folder/'.
# Loading customized repurposing dataset...
# Beginning Downloading Pretrained Model...
# Note: if you have already download the pretrained model before, please stop the program and set the input parameter 'pretrained_dir' to the path
# Downloading finished... Beginning to extract zip file...
# pretrained model Successfully Downloaded...
# Using pretrained model and making predictions...
# repurposing...
# Drug Target Interaction Prediction Mode...
# in total: 82 drug-target pairs
# encoding drug...
# unique drugs: 81
# encoding protein...
# unique target sequence: 1
# Done.
# predicting...
# ---------------
# Predictions from model 1 with drug encoding MPNN and target encoding CNN are done...
# -------------
# repurposing...
# Drug Target Interaction Prediction Mode...
# in total: 82 drug-target pairs
# encoding drug...
# unique drugs: 81
# encoding protein...
# unique target sequence: 1
# Done.
# predicting...
# ---------------
# Predictions from model 2 with drug encoding CNN and target encoding CNN are done...
# -------------
# repurposing...
# Drug Target Interaction Prediction Mode...
# in total: 82 drug-target pairs
# encoding drug...
# unique drugs: 81
# encoding protein...
# unique target sequence: 1
# Done.
# predicting...
# ---------------
# Predictions from model 3 with drug encoding Morgan and target encoding CNN are done...
# -------------
# repurposing...
# Drug Target Interaction Prediction Mode...
# in total: 82 drug-target pairs
# encoding drug...
# unique drugs: 81
# encoding protein...
# unique target sequence: 1
# -- Encoding AAC takes time. Time Reference: 24s for ~100 sequences in a CPU.				 Calculate your time by the unique target sequence #, instead of the entire dataset.
# Done.
# predicting...
# ---------------
# Predictions from model 4 with drug encoding Morgan and target encoding AAC are done...
# -------------
# repurposing...
# Drug Target Interaction Prediction Mode...
# in total: 82 drug-target pairs
# encoding drug...
# unique drugs: 81
# encoding protein...
# unique target sequence: 1
# -- Encoding AAC takes time. Time Reference: 24s for ~100 sequences in a CPU.				 Calculate your time by the unique target sequence #, instead of the entire dataset.
# Done.
# predicting...
# ---------------
# Predictions from model 5 with drug encoding Daylight and target encoding AAC are done...
# -------------
# models prediction finished...
# aggregating results...
# ---------------
# Drug Repurposing Result for SARS-CoV2 3CL Protease
# +------+----------------------+------------------------+---------------+
# | Rank |      Drug Name       |      Target Name       | Binding Score |
# +------+----------------------+------------------------+---------------+
# |  1   |     Daclatasvir      | SARS-CoV2 3CL Protease |     303.23    |
# |  2   |      Vicriviroc      | SARS-CoV2 3CL Protease |     351.13    |
# |  3   |      Darunavir       | SARS-CoV2 3CL Protease |     472.67    |
# |  4   |      Lopinavir       | SARS-CoV2 3CL Protease |     473.82    |
# |  5   |    Fosamprenavir     | SARS-CoV2 3CL Protease |     490.41    |
# |  6   |     Rilpivirine      | SARS-CoV2 3CL Protease |     506.98    |
# |  7   |      Maraviroc       | SARS-CoV2 3CL Protease |     587.14    |
# |  8   |      Amprenavir      | SARS-CoV2 3CL Protease |     604.96    |
# |  9   |      Simeprevir      | SARS-CoV2 3CL Protease |     607.55    |
# |  10  |     Elvitegravir     | SARS-CoV2 3CL Protease |     643.62    |
# |  11  |      Sofosbuvir      | SARS-CoV2 3CL Protease |     661.88    |
# |  12  |      Letermovir      | SARS-CoV2 3CL Protease |     736.80    |
# |  13  |      Nelfinavir      | SARS-CoV2 3CL Protease |     741.86    |
# |  14  |      Peramivir       | SARS-CoV2 3CL Protease |     754.58    |
# |  15  |       Abacavir       | SARS-CoV2 3CL Protease |     757.47    |
# |  16  |     Delavirdine      | SARS-CoV2 3CL Protease |     862.69    |
# |  17  |      Amantadine      | SARS-CoV2 3CL Protease |     881.83    |
# |  18  |      Ritonavir       | SARS-CoV2 3CL Protease |     927.59    |
# |  19  |      Atazanavir      | SARS-CoV2 3CL Protease |     970.85    |
# |  20  |     Raltegravir      | SARS-CoV2 3CL Protease |     979.88    |
# |  21  |      Telaprevir      | SARS-CoV2 3CL Protease |    1039.50    |
# |  22  |      Tenofovir       | SARS-CoV2 3CL Protease |    1062.67    |
# |  23  |       Descovy        | SARS-CoV2 3CL Protease |    1062.67    |
# |  24  |      Saquinavir      | SARS-CoV2 3CL Protease |    1107.73    |
# |  25  |   Podophyllotoxin    | SARS-CoV2 3CL Protease |    1256.31    |
# |  26  |      Efavirenz       | SARS-CoV2 3CL Protease |    1412.96    |
# |  27  |       Arbidol        | SARS-CoV2 3CL Protease |    1417.49    |
# |  28  |     Enfuvirtide      | SARS-CoV2 3CL Protease |    1425.04    |
# |  29  |      Imiquimod       | SARS-CoV2 3CL Protease |    1515.84    |
# |  30  |      Cobicistat      | SARS-CoV2 3CL Protease |    1621.76    |
# checkout ./save_folder/results_aggregation/repurposing.txt for the whole list
